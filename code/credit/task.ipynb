# %% [markdown]
# # 信用逾期预测

# %%
# 导入相关包
import pandas as pd

import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv", encoding="gbk")

# %%
# 查看数据结构
data
# Out:
#       Unnamed: 0   custid                          trade_no bank_card_no  \
# 0              5  2791858  20180507115231274000000023057383          卡号1
# 1             10   534047  20180507121002192000000023073000          卡号1
# 2             12  2849787  20180507125159718000000023114911          卡号1
# 3             13  1809708  20180507121358683000000388283484          卡号1
# 4             14  2499829  20180507115448545000000388205844          卡号1
# ...          ...      ...                               ...          ...
# 4749       11978  3269862  20180507120519228000000388247328          卡号1
# 4750       11986   270952  20180507114937914000000388192877          卡号1
# 4751       11988  2425913  20180507121340509000000388278785          卡号1
# 4752       11991   471395  20180504161827128000000381357758          卡号1
# 4753       11992  1881943  20180507124243041000000388391027          卡号1
#
#       low_volume_percent  middle_volume_percent  \
# ...

# %%
# 查看所有字段，还好缺失值等情况
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4754 entries, 0 to 4753
# Data columns (total 90 columns):
# Unnamed: 0                                    4754 non-null int64
# custid                                        4754 non-null int64
# trade_no                                      4754 non-null object
# bank_card_no                                  4754 non-null object
# low_volume_percent                            4752 non-null float64
# middle_volume_percent                         4752 non-null float64
# take_amount_in_later_12_month_highest         4754 non-null int64
# trans_amount_increase_rate_lately             4751 non-null float64
# trans_activity_month                          4752 non-null float64
# trans_activity_day                            4752 non-null float64
# transd_mcc                                    4752 non-null float64
# trans_days_interval_filter                    4746 non-null float64
# ...

# %%
# 从上面可以找出哪些字段属于类别字段
category_features = ["trade_no", "bank_card_no", "reg_preference_for_trad", "source", "id_name", "latest_query_time"]

# %%
# 我们发现这里有些字段只有单一值或者没有重复的 比如 custid 或者 trade_no 这些可以去掉
data.nunique()
# Out:
# Unnamed: 0               4754
# custid                   4754
# trade_no                 4754
# bank_card_no                1
# low_volume_percent         40
#                          ...
# consfin_product_count      20
# consfin_max_limit         175
# consfin_avg_limit        1677
# latest_query_day          210
# loans_latest_day          235
# Length: 90, dtype: int64

# %%
data["source"].value_counts()
# Out:
# xs    4754
# Name: source, dtype: int64

# %%
# 去除一些没用的列
data.drop(["Unnamed: 0", "custid", "trade_no", "bank_card_no", "source"], axis=1, inplace=True)

# %%
data.head()
# Out:
#    low_volume_percent  middle_volume_percent  \
# 0                0.01                   0.99
# 1                0.02                   0.94
# 2                0.04                   0.96
# 3                0.00                   0.96
# 4                0.01                   0.99
#
#    take_amount_in_later_12_month_highest  trans_amount_increase_rate_lately  \
# 0                                      0                               0.90
# 1                                   2000                               1.28
# 2                                      0                               1.00
# 3                                   2000                               0.13
# 4                                      0                               0.46
#
#    trans_activity_month  trans_activity_day  transd_mcc  \
# 0                  0.55               0.313        17.0
# 1                  1.00               0.458        19.0
# 2                  1.00               0.114        13.0
# ...

# %%
data.describe()
# Out:
#        low_volume_percent  middle_volume_percent  \
# count         4752.000000            4752.000000
# mean             0.021806               0.901294
# std              0.041527               0.144856
# min              0.000000               0.000000
# 25%              0.010000               0.880000
# 50%              0.010000               0.960000
# 75%              0.020000               0.990000
# max              1.000000               1.000000
#
#        take_amount_in_later_12_month_highest  \
# count                            4754.000000
# mean                             1940.197728
# std                              3923.971494
# min                                 0.000000
# 25%                                 0.000000
# 50%                               500.000000
# 75%                              2000.000000
# max                             68000.000000
#
#        trans_amount_increase_rate_lately  trans_activity_month  \
# ...

# %% [markdown]
# # 可视化分析

# %%
# 观察每个数值属性的柱状图
# 我们发现一些字段存在重尾分布，后面需要进一步分析chu'l
data.hist(bins=50, figsize=(30,30))
plt.show()

# %%
# 创建测试集
